# %% [markdown]
# # FUNCIONES MAS COMUNES EN NUMPY

# %%
import numpy as np

# %% [markdown]
# # SHAPE Y RESHAPE

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[8, 1],
#        [3, 3],
#        [6, 2]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(1,6)
# Out:
# array([[8, 1, 3, 3, 6, 2]])

# %%
arr.ndim
# Out:
# 2

# %% [markdown]
# # MAX Y ARGMAX

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([ 6, 16,  6,  8, 11, 12,  5,  1, 11, 15])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[ 6, 16,  6,  8, 11],
#        [12,  5,  1, 11, 15]])

# %%
arr.max()
# Out:
# np.int64(16)

# %%
matriz.max()
# Out:
# np.int64(16)

# %%
arr.argmax()
# Out:
# np.int64(1)

# %% [markdown]
# # MIN Y ARGMIN

# %%
arr.min()
# Out:
# np.int64(1)

# %%
matriz.min()
# Out:
# np.int64(1)

# %%
matriz.min(0)
# Out:
# array([ 6,  5,  1,  8, 11])

# %% [markdown]
# # SORT

# %%
arr
# Out:
# array([ 6, 16,  6,  8, 11, 12,  5,  1, 11, 15])

# %%
arr.sort()
arr
# Out:
# array([ 1,  5,  6,  6,  8, 11, 11, 12, 15, 16])
